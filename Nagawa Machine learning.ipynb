# %%
#machine learning
#train and testing
#confusion matrix
#clustering
#k-means
#k-nearest neighbour

# %%
#create model
import numpy
import matplotlib.pyplot as plt
numpy.random.seed(2)

x=numpy.random.normal(3, 1, 100)
y=numpy.random.normal(150 ,40 ,100) / x

plt.scatter(x,y)
plt.show()

# %%
#split into train/test
#training 80%
#testing 20%
train_x=x[:80]
train_y=y[:80]
test_x=x[:80]
test_y=y[:80]

# %%
plt.scatter(train_x,train_y)

plt.show()

# %%
test_x=x[:20]
test_y=y[:20]
test_x=x[:20]
test_y=y[:20]
plt.scatter(test_x,test_y)
plt.show()

# %%
#Draw a polynomial regresssion line through the trained model
numpy.random.seed(2)

x=numpy.random.normal(3, 1, 100)
y=numpy.random.normal(150 ,40 ,100) / x

train_x=x[:80]
train_y=y[:80]

test_x=x[:20]
test_y=y[:20]
mymodel=numpy.poly1d(numpy.polyfit(train_x,train_y,4))
plt.scatter(train_x,train_y)
linegraph = numpy.linspace(0, 6, 100)

plt.plot(linegraph,mymodel(linegraph))
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
heart_data=pd.read_csv('heart.csv')
heart_data.shape
# Out:
# (918, 12)

# %%
#information about data
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
#uniqueness of data
heart_data.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %%
print(heart_data)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#cleaningDatasets
heart_data.dropna(inplace=True)
heart_data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
heart_data.shape
# Out:
# (918, 12)

# %%
#categorical data values
heart_data.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
# 5   39   M           NAP        120          339          0     Normal    170
# 6   45   F           ATA        130          237          0     Normal    170
# 7   54   M           ATA        110          208          0     Normal    142
# 8   37   M           ASY        140          207          0     Normal    130
# 9   48   F           ATA        120          284          0     Normal    120
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# ...

# %%
#visialization od data
heart_data.plot()
plt.show()

# %%
#apply machine learninh for training our model
#split our datasets | train and test the set
#scikit-learn(sklearn)
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(features,y,text_size=0.2,random_state=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 5>()
#       1 #apply machine learninh for training our model
#       2 #split our datasets | train and test the set
#       3 #scikit-learn(sklearn)
#       4 from sklearn.model_selection import train_test_split
# ----> 5 X_train,X_test,y_train,y_test=train_test_split(features,y,text_size=0.2,random_state=4)
#
# NameError: name 'features' is not defined
